# %%
# Importing necessary Libraries
import csv
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
from tqdm import tqdm
import time

# %%
def get_url(search_item, page_number):
    '''
    This function fetches the URL of the item that you want to search
    '''
    template = 'https://www.flipkart.com/search?q={}&otracker=search&otracker1=search&marketplace=FLIPKART&page={}'
    search_item = search_item.replace(" ","+")
    # Add term query to URL
    url = template.format(search_item, page_number)
    return url

# %%
def extract_phone_model_info(item):
    """
    This function extracts model, price, ram, storage, stars , number of ratings, number of reviews, 
    storage expandable option, display option, camera quality, battery , processor, warranty of a phone model at flipkart
    """
    # Extracting the model of the phone from the 1st card
    model = item.find('div',{'class':"_4rR01T"}).text
    # Extracting Stars from 1st card
    try:
        star = item.find('div',{'class':"_3LWZlK"}).text
    except AttributeError:
        star = ""
    # Extracting Number of Ratings from 1st card
    num_ratings_elem = item.find('span',{'class':"_2_R_DZ"})
    num_ratings = num_ratings_elem.text.replace('\xa0&\xa0'," ; ")[0:num_ratings_elem.text.replace('\xa0&\xa0'," ; ").find(';')].strip() if num_ratings_elem is not None else ''
    # Extracting Number of Reviews from 1st card
    reviews_elem = item.find('span',{'class':"_2_R_DZ"})
    reviews = reviews_elem.text.replace('\xa0&\xa0'," ; ")[reviews_elem.text.replace('\xa0&\xa0'," ; ").find(';')+1:].strip() if reviews_elem is not None else ''
    # Extracting RAM from the 1st card
    ram = item.find('li',{'class':"rgWa7D"}).text[0:item.find('li',{'class':"rgWa7D"}).text.find('|')]
    # Extracting Storage/ROM from 1st card
    storage = item.find('li',{'class':"rgWa7D"}).text[item.find('li',{'class':"rgWa7D"}).text.find('|')+1:][0:10].strip()
    # Extracting whether there is an option of expanding the storage or not
    expandable = item.find('li',{'class':"rgWa7D"}).text[item.find('li',{'class':"rgWa7D"}).text.find('|')+1:][13:]
    # Extracting the display option from the 1st card
    display = item.find_all('li')[1].text.strip()
    # Extracting camera options from the 1st card
    camera = item.find_all('li')[2].text.strip()
    # Extracting the battery option from the 1st card
    battery = item.find_all('li')[3].text if len(item.find_all('li')) > 3 else ""
    # Extracting the processor option from the 1st card
    processor = item.find_all('li')[4].text.strip() if len(item.find_all('li')) > 4 else ""
    # Extracting Warranty from the 1st card
    warranty = item.find("span", {"class": "warrantyText"})  # Extracting Warranty from the 1st card
    if warranty:
        warranty = warranty.text.strip()
    else:
        warranty = "N/A"

    # Extracting price of the model from the 1st card
    try:
        price = item.find('div',{'class':'_30jeq3 _1_WHN1'}).text
    except AttributeError:
        price = ""
    result = (model, star, num_ratings, reviews, ram, storage, expandable, display, camera, battery, processor, warranty, price)
    return result

# %%
def main(search_item):
    '''
    This function will create a dataframe for all the details that we are fetching from all the multiple pages
    '''
    driver = webdriver.Chrome()
    records = []
    models = set()  # create a set to store unique models
    for batch in (range(1, 4)): # iterate in batches of 20 pages
        for page in tqdm(range((batch-1)*20+1, batch*20+1)):
            url = get_url(search_item, page)
            driver.get(url)
            time.sleep(5)  # add a 5-second delay to mimic manual browsing
            soup = BeautifulSoup(driver.page_source,'html.parser')
            results = soup.find_all('a',{'class':"_1fQZEK"})
            for item in results:
                model = item.find('div',{'class':"_4rR01T"}).text
                if model not in models:  # check if model is already extracted
                    records.append(extract_phone_model_info(item))
                    models.add(model)  # add model to set
        # add additional delay between batches to mimic manual browsing behavior
        if batch < 3:
            time.sleep(30)
    driver.close()
    # Saving the data into a csv file
    with open('Flipkart_results.csv','w',newline='',encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(['Model','Stars','Num_of_Ratings','Reviews','Ram','Storage','Expandable',
                        'Display','Camera','Battery','Processor','Warranty','Price'])
        writer.writerows(records)

# %%
# %%time
main('mobile phones')
# Out:
# 100%|██████████| 20/20 [02:13<00:00,  6.70s/it]
# 100%|██████████| 20/20 [02:14<00:00,  6.72s/it]
# 100%|██████████| 20/20 [02:06<00:00,  6.31s/it]
# CPU times: total: 5.2 s
# Wall time: 7min 37s

# %%
mobile_df = pd.read_csv(r"C:\Users\acer\OneDrive\Desktop\AMAZON PRICE PREDICTOR\Flipkart_results.csv")
mobile_df.head()
# Out:
#                                         Model  Stars    Num_of_Ratings  \
# 0  SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)    4.4  1,26,429 Ratings
# 1  SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)    4.4  1,26,429 Ratings
# 2             POCO C50 (Country Green, 32 GB)    4.4     3,353 Ratings
# 3                POCO C50 (Royal Blue, 32 GB)    4.4     3,353 Ratings
# 4  SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)    4.4  1,26,429 Ratings
#
#          Reviews        Ram    Storage              Expandable  \
# 0  7,352 Reviews  4 GB RAM   64 GB ROM    Expandable Upto 1 TB
# 1  7,352 Reviews  4 GB RAM   64 GB ROM    Expandable Upto 1 TB
# 2    160 Reviews  2 GB RAM   32 GB ROM  Expandable Upto 512 GB
# 3    160 Reviews  2 GB RAM   32 GB ROM  Expandable Upto 512 GB
# 4  7,352 Reviews  4 GB RAM   64 GB ROM    Expandable Upto 1 TB
#
#                                 Display                               Camera  \
# 0  16.76 cm (6.6 inch) Full HD+ Display  50MP + 5MP + 2MP | 8MP Front Camera
# 1  16.76 cm (6.6 inch) Full HD+ Display  50MP + 5MP + 2MP | 8MP Front Camera
# 2      16.56 cm (6.52 inch) HD+ Display   8MP Dual Camera | 5MP Front Camera
# 3      16.56 cm (6.52 inch) HD+ Display   8MP Dual Camera | 5MP Front Camera
# 4  16.76 cm (6.6 inch) Full HD+ Display  50MP + 5MP + 2MP | 8MP Front Camera
#
#                             Battery  \
# 0      6000 mAh Lithium Ion Battery
# 1      6000 mAh Lithium Ion Battery
# 2  5000 mAh Lithium Polymer Battery
# 3  5000 mAh Lithium Polymer Battery
# 4      6000 mAh Lithium Ion Battery
#
#                                            Processor  Warranty   Price
# 0                               Exynos 850 Processor       NaN  ₹9,699
# 1                               Exynos 850 Processor       NaN  ₹9,699
# 2  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...       NaN  ₹5,749
# 3  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...       NaN  ₹5,749
# 4                               Exynos 850 Processor       NaN  ₹9,699

# %%
mobile_df.Model.unique()
# Out:
# array(['SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)',
#        'SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)',
#        'POCO C50 (Country Green, 32 GB)', 'POCO C50 (Royal Blue, 32 GB)',
#        'SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)',
#        'REDMI 10 (Caribbean Green, 64 GB)',
#        'REDMI 10 (Midnight Black, 64 GB)',
#        'REDMI 10 (Pacific Blue, 64 GB)',
#        'realme C35 (Glowing Black, 64 GB)',
#        'realme C35 (Glowing Green, 64 GB)',
#        'SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)',
#        'realme C35 (Glowing Green, 128 GB)',
#        'REDMI 10 (Shadow Black, 64 GB)',
#        'realme C35 (Glowing Black, 128 GB)',
#        'SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)',
#        'Infinix HOT 20 Play (Fantasy Purple, 64 GB)',
#        'Infinix HOT 20 Play (Racing Black, 64 GB)',
#        'Infinix HOT 20 Play (Aurora Green, 64 GB)',
#        'Infinix HOT 20 Play (Luna Blue, 64 GB)',
#        'SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)',
#        'SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)',
#        'MOTOROLA e40 (Carbon Gray, 64 GB)',
#        'SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)',
#        'SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)',
#        'vivo T1 44W (Midnight Galaxy, 128 GB)',
#        'vivo T1 44W (Starry Sky, 128 GB)',
#        'MOTOROLA g52 (Metallic White, 128 GB)',
#        'MOTOROLA e13 (Aurora Green, 64 GB)',
#        'APPLE iPhone 11 (White, 64 GB)',
#        'Infinix Hot 12 (7° Purple, 64 GB)',
#        'Infinix Hot 12 (Exploratory Blue, 64 GB)',
#        'Infinix SMART 7 (Azure Blue, 64 GB)',
#        'MOTOROLA G32 (Mineral Gray, 64 GB)',
#        'Infinix Smart 6 HD (Origin Blue, 32 GB)',
#        'MOTOROLA e13 (Cosmic Black, 64 GB)',
#        'POCO M4 Pro 5G (Yellow, 128 GB)',
#        'POCO M4 Pro 5G (Cool Blue, 128 GB)',
#        'MOTOROLA g31 (Meteorite Grey, 64 GB)',
#        'Infinix Hot 12 (Turquoise Cyan, 64 GB)',
#        'APPLE iPhone 14 (Blue, 128 GB)',
#        'Infinix Hot 12 (Polar Black, 64 GB)',
#        'MOTOROLA G62 5G (Frosted Blue, 128 GB)',
#        'MOTOROLA g22 (Cosmic Black, 64 GB)',
#        'POCO M4 5G (Cool Blue, 64 GB)', 'POCO M4 5G (Power Black, 64 GB)',
#        'SAMSUNG Galaxy F04 (Jade Purple, 64 GB)',
#        'APPLE iPhone 11 (Black, 64 GB)',
#        'MOTOROLA G32 (Satin Silver, 64 GB)',
#        'APPLE iPhone 14 Plus (Purple, 128 GB)',
#        'Infinix NOTE 12i (Metaverse Blue, 64 GB)',
#        'SAMSUNG Galaxy F04 (Opal Green, 64 GB)',
#        'Google Pixel 6a (Chalk, 128 GB)',
#        'Infinix Hot 12 Pro (Electric Blue, 64 GB)',
#        'POCO X4 Pro 5G (Yellow, 128 GB)',
#        'APPLE iPhone 14 Plus (Midnight, 128 GB)',
#        'POCO X4 Pro 5G (Laser Black, 128 GB)', 'Nokia 105 SS',
#        'OPPO A17k (Gold, 64 GB)', 'OPPO A17k (Navy Blue, 64 GB)',
#        'REDMI Note 10S (Frost White, 64 GB)',
#        'POCO M4 Pro (Cool Blue, 128 GB)',
#        'REDMI 9i Sport (Carbon Black, 64 GB)',
#        'MOTOROLA g72 (Polar Blue, 128 GB)',
#        'MOTOROLA g82 5G (Meterorite Grey, 128 GB)',
#        'OPPO A17 (Lake Blue, 64 GB)', 'vivo T1X (Space Blue, 64 GB)',
#        'vivo T1X (Gravity Black, 64 GB)',
#        'vivo T1X (Gravity Black, 128 GB)',
#        'APPLE iPhone 14 (Midnight, 128 GB)',
#        'Infinix Hot 20 5G (Blaster Green, 128 GB)',
#        'Infinix Hot 20 5G (Space Blue, 128 GB)',
#        'POCO M4 Pro (Yellow, 128 GB)',
#        'Infinix NOTE 12i (Alpine White, 64 GB)',
#        'Infinix NOTE 12i (Force Black, 64 GB)',
#        'POCO M4 Pro (Cool Blue, 64 GB)', 'POCO M4 5G (Cool Blue, 128 GB)',
#        'POCO X4 Pro 5G (Laser Blue, 128 GB)',
#        'POCO X5 Pro 5G (Horizon Blue, 256 GB)',
#        'Google Pixel 6a (Charcoal, 128 GB)',
#        'APPLE iPhone 13 (Midnight, 128 GB)',
#        'APPLE iPhone 13 (Pink, 128 GB)', 'vivo T1X (Space Blue, 128 GB)',
#        'REDMI 10 (Midnight Black, 128 GB)',
#        'realme C33 (Sandy Gold, 64 GB)', 'realme C33 (Night Sea, 64 GB)',
#        'realme C33 (Aqua Blue, 32 GB)', 'realme C33 (Sandy Gold, 32 GB)',
#        'realme C33 (Night Sea, 32 GB)',
#        'Infinix Hot 12 Pro (Lightsaber Green, 64 GB)',
#        'SAMSUNG Galaxy M33 5G (Mystique Green, 128 GB)',
#        'POCO X4 Pro 5G (Laser Blue, 64 GB)',
#        'Infinix Zero 5G 2023 (Submariner Black, 128 GB)',
#        'POCO X5 Pro 5G (Astral Black, 128 GB)',
#        'MOTOROLA e32 (Arctic Blue, 64 GB)',
#        'realme 9i 5G (Rocking Black, 64 GB)',
#        'POCO C31 (Shadow Gray, 64 GB)',
#        'OPPO A17 (Sunlight Orange, 64 GB)',
#        'OPPO A17 (Midnight Black, 64 GB)',
#        'OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)',
#        'SAMSUNG Galaxy M04 (Light Green, 64 GB)',
#        'REDMI A1 (Black, 32 GB)', 'REDMI A1 (Light Green, 32 GB)',
#        'REDMI A1 (Light Blue, 32 GB)',
#        'vivo T1 Pro 5G (Turbo Cyan, 128 GB)',
#        'MOTOROLA G62 5G (Midnight Gray, 128 GB)',
#        'realme C30 (Lake Blue, 32 GB)', 'realme C30 (Denim Black, 32 GB)',
#        'REDMI 9i Sport (Coral Green, 64 GB)',
#        'realme C33 (Aqua Blue, 64 GB)',
#        'realme 9i 5G (Metallica Gold, 64 GB)',
#        'realme C30s (Stripe Blue, 32 GB)',
#        'realme C30s (Stripe Black, 32 GB)',
#        'realme C30 (Bamboo Green, 32 GB)',
#        'APPLE iPhone 13 (Starlight, 128 GB)',
#        'APPLE iPhone 14 Plus (Blue, 128 GB)',
#        'Infinix Hot 12 Pro (Halo White, 64 GB)',
#        'REDMI 10A (Slate Grey, 32 GB)', 'APPLE iPhone 13 (Blue, 128 GB)',
#        'POCO C55 (Cool Blue, 64 GB)', 'POCO M4 Pro (Power Black, 128 GB)',
#        'vivo Y01 (Sapphire Blue, 32 GB)', 'POCO C31 (Royal Blue, 64 GB)',
#        'POCO C55 (Cool Blue, 128 GB)',
#        'realme 9i 5G (Soulful Blue, 64 GB)',
#        'vivo T1 Pro 5G (Turbo Black, 128 GB)',
#        'Infinix HOT 20 5G (Space Blue, 64 GB)',
#        'vivo Y35 (Agate Black, 128 GB)', 'LAVA Hero 600i',
#        'MOTOROLA g82 5G (White Lily, 128 GB)',
#        'realme C11 2021 (Cool Blue, 32 GB)',
#        'realme C11 2021 (Cool Grey, 32 GB)', 'LAVA Gem',
#        'REDMI 10 Power (Power Black, 128 GB)',
#        'OPPO F19 (Midnight Blue, 128 GB)',
#        'APPLE iPhone 14 Plus (Starlight, 128 GB)',
#        'POCO X4 Pro 5G (Yellow, 64 GB)', 'POCO C55 (Power Black, 64 GB)',
#        'Nokia 150 DS 2020', 'Nokia 105 TA-1416 DS',
#        'POCO C55 (Forest Green, 128 GB)',
#        'POCO C55 (Power Black, 128 GB)',
#        'OPPO F19 Pro+ 5G (Fluid Black, 128 GB)',
#        'Infinix Hot 12 Pro (Racing Black, 64 GB)',
#        'Nothing Phone (1) (White, 256 GB)',
#        'Nothing Phone (1) (Black, 128 GB)',
#        'Nothing Phone (1) (Black, 256 GB)',
#        'Infinix Hot 12 Pro (Electric Blue, 128 GB)',
#        'REDMI 10 (Pacific Blue, 128 GB)',
#        'Micromax IN 2C (Silver, 32 GB)', 'SAMSUNG Guru Music 2',
#        'OPPO F19 Pro+ 5G (Space Silver, 128 GB)',
#        'realme NARZO 50A PRIME (FLASH BLUE, 64 GB)',
#        'POCO C55 (Forest Green, 64 GB)',
#        'Infinix Note 12 5G (Snowfall, 64 GB)',
#        'REDMI Note 11 (Space Black, 128 GB)',
#        'MOTOROLA g72 (Meteorite Grey, 128 GB)', 'GFive U707',
#        'realme Narzo 50i Prime (Dark Blue, 64 GB)',
#        'vivo Y35 (Dawn Gold, 128 GB)', 'vivo Y15s (Wave Green, 32 GB)',
#        'POCO M4 5G (Yellow, 128 GB)',
#        'REDMI Note 12 Pro 5G (Glacier Blue, 128 GB)',
#        'POCO M5 (Power Black, 128 GB)',
#        'realme Narzo 50 (Speed Black, 128 GB)',
#        'REDMI 9i Sport (Metallic Blue, 64 GB)', 'Micromax J22',
#        'Infinix Note 12 Pro (Tuscany Blue, 256 GB)',
#        'SAMSUNG Galaxy A14 5G (Dark Red, 64 GB)',
#        'Infinix Hot 12 Pro (Lightsaber Green, 128 GB)',
#        'vivo Y16 (Drizzling Gold, 64 GB)',
#        'vivo Y16 (Drizzling Gold, 32 GB)',
#        'REDMI 11 Prime 5G (Thunder Black, 128 GB)',
#        'Infinix Note 12 (Jewel Blue, 128 GB)', 'itel It2171',
#        'vivo T1 5G (Rainbow Fantasy, 128 GB)',
#        'POCO X5 Pro 5G (Yellow, 128 GB)',
#        'Infinix Note 12 (Jewel Blue, 64 GB)',
#        'MOTOROLA e13 (Creamy White, 64 GB)',
#        'realme 10 Pro+ 5G (Nebula Blue, 128 GB)',
#        'Infinix Note 12 (Force Black, 64 GB)',
#        'realme 10 Pro+ 5G (Dark Matter, 128 GB)',
#        'REDMI 10A (Charcoal Black, 64 GB)',
#        'REDMI 10A (Slate grey, 64 GB)',
#        'REDMI Note 11 (Starburst White, 64 GB)',
#        'REDMI Note 11 (Horizon Blue, 64 GB)',
#        'realme 10 Pro+ 5G (Nebula Blue, 256 GB)',
#        'realme Narzo 50 (Speed Black, 64 GB)',
#        'REDMI 10A (Charcoal Black, 32 GB)',
#        'Redmi 10 Prime (Phantom Black, 128 GB)',
#        'IQOO Z6 Lite 5G (Without Charger) (Mystic Night, 128 GB)',
#        'IQOO Z6 Lite 5G (Without Charger) (Stellar Green, 128 GB)',
#        'Infinix HOT 20 5G (Blaster Green, 64 GB)',
#        'realme 10 (Clash White, 64 GB)', 'LAVA A3',
#        'realme 10 (Rush Black, 128 GB)', 'realme 10 (Rush Black, 64 GB)',
#        'itel Ace 2', 'SAMSUNG GALAXY M13 5G (Aqua Green, 64 GB)',
#        'MOTOROLA edge 30 (Meteor Grey, 128 GB)',
#        'Infinix Hot 20 5G (Racing Black, 128 GB)',
#        'realme C11 2021 (Cool Grey, 64 GB)',
#        'realme C11 2021 (Cool Blue, 64 GB)',
#        'vivo Y02 (Cosmic Grey, 32 GB)', 'SAMSUNG GURU MUSIC 2',
#        'SAMSUNG Galaxy F22 (Denim Blue, 128 GB)',
#        'realme 9i 5G (Rocking Black, 128 GB)',
#        'SAMSUNG Galaxy S21 FE 5G (Olive, 128 GB)', 'LAVA A1 Josh 2021',
#        'MOTOROLA g22 (Mint Green, 64 GB)',
#        'vivo Y15s (Mystic Blue, 32 GB)', 'POCO M5 (Icy Blue, 64 GB)',
#        'SAMSUNG Galaxy M32 Prime Edition (Light Blue, 128 GB)',
#        'POCO M5 (Icy Blue, 128 GB)', 'OPPO A77s (Starry Black, 128 GB)',
#        'vivo Y21 (Diamond Glow, 64 GB)',
#        'REDMI Note 12 Pro 5G (Onyx Black, 128 GB)',
#        'vivo Y16 (Steller Black, 64 GB)', 'OPPO K10 (Blue Flame, 128 GB)',
#        'OPPO K10 (Black Carbon, 128 GB)',
#        'OPPO F19 (Prism Black, 128 GB)',
#        'SAMSUNG Galaxy S21 FE 5G (Lavender, 128 GB)',
#        'Infinix Note 12 Pro 5G (Force Black, 128 GB)',
#        'Infinix Note 12 Pro 5G (Snowfall, 128 GB)',
#        'APPLE iPhone 11 (Black, 128 GB)', 'Micromax X412',
#        'REDMI Note 12 Pro 5G (Stardust Purple, 256 GB)',
#        'Realme C30 - Locked with Airtel Prepaid (Bamboo Green, 32 GB)',
#        'OPPO F19s (Glowing Gold, 128 GB)',
#        'Infinix Note 12 Pro (Volcanic Grey, 256 GB)',
#        'POCO C31 (Royal Blue, 32 GB)',
#        'Tecno Spark 9T (Atlantic Blue, 64 GB)',
#        'MOTOROLA e32 (Eco Black, 64 GB)',
#        'Tecno Camon 19 (Sea Salt White, 128 GB)', 'Micromax X818',
#        'REDMI Note 12 Pro+ 5G (Obsidian Black, 256 GB)',
#        'OnePlus 10R (Forest Green, 128 GB)',
#        'REDMI Note 11 SE (Cosmic White, 64 GB)',
#        'SAMSUNG Galaxy A03 Core (Mint, 32 GB)',
#        'REDMI Note 12 Pro 5G (Stardust Purple, 128 GB)',
#        'Infinix HOT 12 Play (Horizon Blue, 64 GB)',
#        'realme C30s (Stripe Black, 64 GB)',
#        'realme C30s (Stripe Blue, 64 GB)',
#        'SAMSUNG GALAXY M13 (Midnight Blue, 64 GB)',
#        'realme 10 Pro 5G (Nebula Blue, 128 GB)',
#        'Infinix HOT 20 5G (Racing Black, 64 GB)',
#        'OPPO A77s (Sunset Orange, 128 GB)', 'Nokia 150 TA-1235 DS',
#        'REDMI 11 Prime 5G (Thunder Black, 64 GB)',
#        'APPLE iPhone 14 (Blue, 256 GB)',
#        'REDMI 10A SPORT (SLATE GREY, 128 GB)',
#        'SAMSUNG Galaxy A03 Core (Onyx, 32 GB)',
#        'OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)',
#        'itel Vision3 (Multi Green, 32 GB)',
#        'OPPO K10 5G (Midnight Black, 128 GB)',
#        'realme 10 Pro+ 5G (Hyperspace, 128 GB)',
#        'realme 10 (Clash White, 128 GB)',
#        'OPPO Reno8T 5G (Midnight Black, 128 GB)',
#        'OPPO Reno8T 5G (Sunrise Gold, 128 GB)',
#        'APPLE iPhone 11 (White, 128 GB)',
#        'REDMI Note 12 Pro 5G (Glacier Blue, 256 GB)',
#        'POCO M4 Pro (Yellow, 64 GB)',
#        'realme Narzo 50 (Speed Blue, 64 GB)',
#        'realme Narzo 50 (Speed Blue, 128 GB)',
#        'Infinix HOT 12 Play (Racing Black, 64 GB)',
#        'Infinix HOT 12 Play (Champagne Gold, 64 GB)', 'LAVA GEM',
#        'SAMSUNG Galaxy A14 5G (Black, 64 GB)',
#        'Micromax IN 2C (Brown, 32 GB)',
#        'REDMI Note 12 5G (Matte Black, 128 GB)',
#        'REDMI Note 12 5G (Frosted Green, 128 GB)',
#        'IQOO Z6 Lite 5G (Stellar Green, 128 GB)',
#        'I Kall Z19Pro (Blue, 64 GB)', 'POCO M5 (Yellow, 128 GB)',
#        'SAMSUNG Galaxy A14 5G (Light Green, 64 GB)', 'LAVA A1 2021',
#        'SAMSUNG Galaxy A03 Core (Bronze, 32 GB)',
#        'vivo Y22 (Metaverse Green, 64 GB)',
#        'APPLE iPhone 14 (Starlight, 256 GB)',
#        'Tecno Spark 9 (Infinity Black, 64 GB)',
#        'MOTOROLA G40 Fusion (Frosted Champagne, 128 GB)', 'KARBONN KX3',
#        'REDMI Note 12 Pro+ 5G (Arctic White, 256 GB)',
#        'realme 9 Pro 5G (Sunrise Blue, 128 GB)', 'Energizer M1',
#        'LAVA A1', 'vivo T1 5G (Starlight Black, 128 GB)',
#        'Redmi 9A Sport (Metallic Blue, 32 GB)',
#        'Redmi 9A Sport (Coral Green, 32 GB)',
#        'Redmi 9A Sport (Carbon Black, 32 GB)',
#        'REDMI Note 11 (Horizon Blue, 128 GB)',
#        'SAMSUNG Galaxy A23 5G (Silver, 128 GB)',
#        'REDMI 10A (Sea Blue, 64 GB)',
#        'APPLE iPhone 14 Plus (Starlight, 256 GB)',
#        'OPPO K10 5G (Ocean Blue, 128 GB)',
#        'POCO X5 Pro 5G (Yellow, 256 GB)',
#        'REDMI Note 12 Pro 5G (Onyx Black, 256 GB)',
#        'POCO M4 Pro 5G (Cool Blue, 64 GB)',
#        'realme 9i (Prism Blue, 64 GB)',
#        'SAMSUNG GALAXY M13 (Aqua Green, 64 GB)',
#        'Infinix HOT 12 Play (Daylight Green, 64 GB)',
#        'vivo V27 Pro 5G (Magic Blue, 128 GB)',
#        'MOTOROLA E7 Power (Tahiti Blue, 64 GB)',
#        'vivo V27 Pro 5G (Noble Black, 256 GB)', 'Micromax X413',
#        'GREENBERRI RAFALE', 'vivo V27 Pro 5G (Magic Blue, 256 GB)',
#        'Nokia 105SS PLUS', 'Nokia 105 PLUS', 'LAVA Hero Punch',
#        'Micromax X512', 'vivo Y33s (Mirror Black, 128 GB)',
#        'Kechaoda K115', 'REDMI Note 11 (Space Black, 64 GB)',
#        'MOTOROLA Edge 30 (Aurora Green, 128 GB)',
#        'itel Vision1 (Gradation Blue, 32 GB)', 'SAMSUNG Guru 1200',
#        'Infinix Zero 5G 2023 (Coral Orange, 128 GB)',
#        'realme C20 (Cool Grey, 32 GB)',
#        'SAMSUNG Galaxy A23 5G (Orange, 128 GB)',
#        'Tecno Pova Neo (Geek Blue, 128 GB)',
#        'POCO F4 5G (Night Black, 128 GB)',
#        'realme C31 (Light Silver, 64 GB)',
#        'REDMI Note 10T 5G (Mint Green, 128 GB)', 'Motorola a70',
#        'Infinix Zero 5G 2023 TURBO (Submariner Black, 256 GB)',
#        'itel Ace2 Star', 'REDMI A1+ (Black, 32 GB)',
#        'realme 9i 5G (Metallica Gold, 128 GB)',
#        'vivo Y22 (Starlit Blue, 64 GB)',
#        'vivo Y22 (Metaverse Green, 128 GB)',
#        'MOTOROLA G60 (Moonless, 128 GB)',
#        'realme 9 Pro 5G (Midnight Black, 128 GB)',
#        'SAMSUNG Galaxy S21 FE 5G (Graphite, 128 GB)',
#        'realme 10 Pro 5G (Dark Matter, 128 GB)',
#        'realme 10 Pro 5G (Hyperspace, 128 GB)',
#        'REDMI 10 Prime (Bifrost Blue, 128 GB)',
#        'REDMI 10 Prime (Astral White, 128 GB)',
#        'Google Pixel 7 (Obsidian, 128 GB)',
#        'Google Pixel 7 (Lemongrass, 128 GB)',
#        'Google Pixel 7 (Snow, 128 GB)',
#        'SAMSUNG Galaxy F22 (Denim Blue, 64 GB)', 'LAVA A3 Power',
#        'SAMSUNG Galaxy M04 (Dark Blue, 128 GB)',
#        'Infinix Note 12 (Force Black, 128 GB)', 'MU M5000',
#        'vivo Y100 5G (Pacific Blue, 128 GB)',
#        'vivo Y100 5G (Twilight Gold, 128 GB)',
#        'SAMSUNG Galaxy F22 (Denim Black, 64 GB)',
#        'OPPO F21 Pro (Cosmic Black, 128 GB)',
#        'Tecno Pop 5 Pro (Ice Blue, 32 GB)',
#        'OPPO F21 Pro (Sunset Orange, 128 GB)',
#        'IQOO Z6 Lite 5G (Without Charger) (Stellar Green, 64 GB)',
#        'vivo Y21G (Diamond Glow, 64 GB)',
#        'realme 9i 5G (Soulful Blue, 128 GB)',
#        'realme C20 (Cool Blue, 32 GB)',
#        'SAMSUNG GALAXY M13 (Stardust Brown, 64 GB)',
#        'Motorola Edge 30 Pro (Cosmos Blue, 128 GB)',
#        'vivo Y75 (Dancing waves, 128 GB)',
#        'REDMI Note 12 Pro+ 5G (Iceberg Blue, 256 GB)', 'Micromax X778',
#        'realme 8 5G (Supersonic Blue, 128 GB)',
#        'realme Narzo 50i (Mint Green, 32 GB)', 'Motorola a10',
#        'realme C31 (Light Silver, 32 GB)',
#        'Infinix SMART 7 (Night Black, 64 GB)',
#        'REDMI Note 10T 5G (Graphite Black, 128 GB)', 'Nokia 105 ss',
#        'SAMSUNG Guru Music 2 SM-B315E', 'LAVA Flip',
#        'realme 8i (Space Black, 64 GB)', 'itel A23S (Sky Cyan, 32 GB)',
#        'realme 8i (Space Purple, 64 GB)',
#        'APPLE iPhone 14 (Midnight, 256 GB)',
#        'Tecno Pop 6 Pro (Peaceful Blue, 32 MB)',
#        'Tecno Pop 6 Pro (Polar Black, 32 GB)',
#        'realme 9i (Prism Blue, 128 GB)', 'Nokia TA-1174 / TA-1299',
#        'Kechaoda K112', 'Micromax X708',
#        'APPLE iPhone 14 (Starlight, 128 GB)',
#        'IQOO Z6 44W (Lumina Blue, 128 GB)', 'itel IT5626',
#        'SAMSUNG Galaxy A14 5G (Dark Red, 128 GB)',
#        'Infinix Note 12 TURBO (Jewel Blue, 128 GB)',
#        'Infinix Note 12 TURBO (Force Black, 128 GB)',
#        'MOTOROLA e40 (Pink Clay, 64 GB)',
#        'Infinix Smart 6 (Polar Black, 64 GB)', 'Micromax X809',
#        'realme 9 5G (Meteor Black, 64 GB)',
#        'realme Narzo 50i Prime (Mint Green, 64 GB)',
#        'POCO X5 Pro 5G (Astral Black, 256 GB)',
#        'realme 9 5G (Stargaze White, 64 GB)',
#        'realme 9 5G (Stargaze White, 128 GB)',
#        'REDMI 9i (Midnight Black, 64 GB)',
#        'itel A49 (Crystal Purple, 32 GB)', 'itel A49 (Sky Cyan, 32 GB)',
#        'Infinix Smart 6 (Light Sea Green, 64 GB)',
#        'IQOO Neo 6 5G (Dark Nova, 128 GB)',
#        'POCO M5 (Power Black, 64 GB)',
#        'MOTOROLA g22 (Iceberg Blue, 64 GB)',
#        'REDMI 9 Activ (Coral Green, 128 GB)',
#        'MOTOROLA g52 (Metallic White, 64 GB)',
#        'vivo Y21T (Midnight Blue, 128 GB)', 'Kechaoda A26',
#        'vivo Y33T (Starry Gold, 128 GB)',
#        'Kechaoda K66 The Music House 4',
#        'REDMI Note 10T 5G (Chromium White, 64 GB)',
#        'itel A23S (Ocean Blue, 32 GB)', 'realme 8 (Cyber Black, 128 GB)',
#        'realme 8 (Cyber Silver, 128 GB)',
#        'APPLE iPhone 14 (Purple, 256 GB)',
#        'OPPO A78 5G (Glowing Black, 128 GB)', 'itel Muzik 400',
#        'POCO M5 (Yellow, 64 GB)', 'Infinix Smart 5A (Ocean Wave, 32 GB)',
#        'Infinix Smart 5A (Midnight Black, 32 GB)',
#        'Infinix Hot 11 (Silver Wave, 64 GB)',
#        'OPPO A57 (Glowing Gold, 64 GB)', 'itel Magic3 Smart Touch Keypad',
#        'vivo Y22 (Starlit Blue, 128 GB)',
#        'MOTOROLA Edge 30 Fusion (Cosmic grey, 128 GB)',
#        'Tecno Spark 8 Pro (Turquoise Cyan, 64 GB)',
#        'APPLE iPhone 13 (Midnight, 256 GB)',
#        'Tecno Spark 8 Pro (Interstellar Black, 64 GB)', 'Micromax X513+',
#        'DIZO Star 500', 'IQOO Z6 44W (Raven Black, 128 GB)',
#        'vivo Y21A (Diamond Glow, 64 GB)', 'Nokia 125 TA-1253 DS',
#        'Infinix Smart 6 (Starry Purple, 64 GB)',
#        'Infinix Smart 6 (Heart Of Ocean, 64 GB)', 'itel it2175',
#        'REDMI 11 Prime 5G (Chrome Silver, 128 GB)',
#        'realme 9 5G (Meteor Black, 128 GB)',
#        'realme 8i (Space Black, 128 GB)',
#        'APPLE iPhone 14 ((PRODUCT)RED, 128 GB)',
#        'realme 9 5G (Supersonic Blue, 64 GB)',
#        'APPLE iPhone 14 Plus ((PRODUCT)RED, 128 GB)',
#        'REDMI Note 11 Pro (Stealth Black, 128 GB)',
#        'REDMI Note 10S (Frost White, 128 GB)',
#        'Google Pixel 7 Pro (Obsidian, 128 GB)',
#        'Google Pixel 7 Pro (Hazel, 128 GB)',
#        'SAMSUNG Galaxy M32 Prime Edition (Black, 64 GB)',
#        'vivo Y53s (Deep Sea Blue, 128 GB)',
#        'Tecno Pova 3 (Eco Black, 64 GB)',
#        'REDMI 10 Prime (Phantom Black, 128 GB)',
#        'REDMI 10A (Sea Blue, 32 GB)',
#        'itel Vision 3 (Deep Ocean Black, 64 GB)',
#        'OnePlus Nord 2T 5G (Jade Fog, 128 GB)',
#        'itel A49 (Dome Blue, 32 GB)',
#        'realme Narzo 50A (Oxygen Green, 128 GB)',
#        'realme 9 Pro 5G (Aurora Green, 128 GB)',
#        'Tecno Spark Go 2022 (Atlantic Blue, 32 GB)',
#        'APPLE iPhone 12 (Purple, 64 GB)', 'itel Power 410',
#        'MOTOROLA g82 5G(White Lily, 128 GB)',
#        'realme 8 5G (Supersonic Black, 64 GB)',
#        'realme 8 5G (Supersonic Black, 128 GB)',
#        'Nokia 110 Dual Sim 2022', 'itel A23S (Sky Black, 32 GB)',
#        'SAMSUNG Galaxy A14 5G (Light Green, 128 GB)', 'Micromax S115',
#        'REDMI Note 12 5G (Mystique Blue, 128 GB)',
#        'realme Narzo 50i (Mint Green, 64 GB)', 'itel Power 110',
#        'OPPO F21s Pro 5G (Starlight Black, 128 GB)',
#        'Infinix Zero 20 (DEEP GRAY, 128 GB)',
#        'realme C21 (Cross Black, 32 GB)',
#        'Infinix Smart 5A (Quetzal Cyan, 32 GB)',
#        'APPLE iPhone 12 (Black, 64 GB)', 'realme C21 (Cross Blue, 32 GB)',
#        'Infinix Zero 20 (Glitter Gold, 128 GB)', 'Kechaoda K33',
#        'realme C21 (Cross Black, 64 GB)',
#        'SAMSUNG Galaxy F12 (Sky Blue, 64 GB)',
#        'Micromax IN Note 1 (Green, 64 GB)', 'Kechaoda K28',
#        'Micromax IN Note 1 (White, 64 GB)',
#        'SAMSUNG GALAXY M13 5G (Stardust Brown, 64 GB)',
#        'realme 9 (Meteor Black, 128 GB)',
#        'realme 9 (Sunburst Gold, 128 GB)',
#        'OPPO A55 (Starry Black, 128 GB)',
#        'OPPO A55 (Rainbow Blue, 128 GB)', 'OPPO A55 (Mint Green, 128 GB)',
#        'vivo Y56 5G (Orange Shimmer, 128 GB)',
#        'REDMI Note 9 (Shadow Black, 128 GB)', 'I Kall K88 PRO 4G Keypad',
#        'realme 50A Prime (Flash Blue, 64 GB)', 'Nokia 5310ds',
#        'vivo Y21T (Pearl White, 128 GB)',
#        'Tecno Spark 8C (Diamond Grey, 64 GB)', 'Nokia 125 DS 2020',
#        'SAMSUNG Galaxy A53 (Awesome Blue, 128 GB)',
#        'vivo V23e 5G (Sunshine Gold, 128 GB)',
#        'SAMSUNG Galaxy F12 (Sea Green, 64 GB)',
#        'REDMI Note 10S (Shadow Black, 128 GB)',
#        'Tecno Spark 8C (Turquoise Cyan, 64 GB)',
#        'OPPO A16E (Blue, 32 GB)', 'REDMI 10A SPORT (SEA BLUE, 128 GB)',
#        'REDMI 11 Prime (Playful Green, 128 GB)',
#        'REDMI 11 Prime (Playful Green, 64 GB)',
#        'OPPO A57 (Glowing Black, 64 GB)', 'Nokia TA-1304/105 SS',
#        'SAMSUNG Galaxy M32 (Light Blue, 128 GB)',
#        'realme narzo 50 5G (Hyper Black, 128 GB)',
#        'Nokia C01 Plus (Blue, 32 GB)',
#        'MOTOROLA G40 Fusion (Frosted Champagne, 64 GB)',
#        'SAMSUNG Galaxy S22 Plus 5G (Phantom Black, 128 GB)',
#        'vivo V21 5G (Dusk Blue, 128 GB)', 'OPPO A 78 5G (Black, 128 GB)',
#        'I Kall K3310', 'KARBONN K110i', 'Nokia 110 DS',
#        'realme C31 (Dark Green, 64 GB)',
#        'realme 9 Pro+ 5G (Aurora Green, 128 GB)',
#        'Redmi 8 (Sapphire Blue, 64 GB)',
#        'realme 9 Pro+ 5G (Sunrise Blue, 256 GB)', 'Nokia 110 TA-1302 DS',
#        'realme 9 Pro+ 5G (Sunrise Blue, 128 GB)',
#        'realme 9 (Stargaze White, 128 GB)', 'LAVA A1 super',
#        'POCO M4 Pro 5G (Power Black, 128 GB)',
#        'Infinix Note 11 (Graphite Black, 128 GB)', 'KARBONN K531',
#        'APPLE iPhone 14 Pro Max (Gold, 128 GB)', 'Nokia 5310 TA-1212 DS',
#        'REDMI Note 10 Pro (Glacial Blue, 128 GB)',
#        'vivo Y33T (Mid day dream, 128 GB)',
#        'APPLE iPhone 13 (Pink, 256 GB)', 'Kechaoda A27', 'itel Power 430',
#        'LAVA A1 Josh',
#        'Redmi Note 11 PRO Plus 5G (Stealth Black, 128 GB)',
#        'Tecno Spark 8P (Turquoise Cyan, 64 GB)',
#        'MOTOROLA G40 Fusion (Dynamic Gray, 64 GB)',
#        'vivo Y21E (Diamond Glow, 64 GB)', 'LAVA A7',
#        'Micromax IN 1 (Blue, 64 GB)', 'Nokia C01 Plus (Grey, 16 GB)',
#        'Infinix Note 11s (Symphony Cyan, 64 GB)',
#        'Motorola Edge 30 Pro (Stardust White, 128 GB)', 'MU M370',
#        'SAMSUNG GALAXY M13 5G (Midnight Blue, 128 GB)',
#        'REDMI Note 10 Pro (Dark Night, 128 GB)',
#        'APPLE iPhone 14 Pro Max (Deep Purple, 128 GB)',
#        'vivo Y21G (Midnight Blue, 64 GB)',
#        'APPLE iPhone 14 Plus (Purple, 256 GB)',
#        'REDMI Note 10S (Shadow Black, 64 GB)',
#        'APPLE iPhone 14 Pro (Deep Purple, 128 GB)',
#        'SAMSUNG Galaxy M32 Prime Edition (Black, 128 GB)',
#        'Nokia 2660 TA-1480 DS', 'APPLE iPhone 12 (Black, 128 GB)',
#        'Nokia 3310 DS 2020', 'Tecno Spark 9 (Sky Mirror, 64 GB)',
#        'OPPO A78 5G (Glowing Blue, 128 GB)',
#        'IQOO Z6 44W (Ravan Black, 128 GB)', 'KARBONN K9 max',
#        'Cellecor E8', 'Redmi 7A (Matte Gold, 32 GB)',
#        'Tecno Spark 9 (Sky Mirror, 128 GB)',
#        'realme Narzo 20 (Victory Blue, 128 GB)',
#        'OPPO F21s Pro (Starlight Black, 128 GB)',
#        'APPLE iPhone 12 (Red, 128 GB)', 'Redmi 7A (Matte Black, 32 GB)',
#        'OPPO A57 (Glowing Green, 64 GB)',
#        'Infinix Note 11s (Mithril Grey, 64 GB)',
#        'Infinix Smart 6 Plus (Crystal Violet, 64 GB)',
#        'SAMSUNG Galaxy A13 (Black, 128 GB)',
#        'Mi 11 Lite (Tuscany Coral, 128 GB)',
#        'Xiaomi 12 Pro 5G (Noir Black, 256 GB)', 'Nokia 105 PLUS SS',
#        'SAMSUNG Galaxy M04 (Dark Blue, 64 GB)', 'OPPO A16E (Blue, 64 GB)',
#        'OPPO A16E (White, 32 GB)', 'Infinix Hot 10S (95° Black, 64 GB)',
#        'OPPO A12 (Blue, 32 GB)', 'LAVA A1200',
#        'POCO M3 Pro 5G (Yellow, 128 GB)',
#        'SAMSUNG Galaxy M32 (Black, 128 GB)',
#        'SAMSUNG Galaxy A73 5G (Awesome Mint, 256 GB)',
#        'MOTOROLA E7 Power (Tahiti Blue, 32 GB)',
#        'SAMSUNG Galaxy A53 (Awesome Black, 128 GB)',
#        'itel A27 (Deep Gray, 32 GB)',
#        'realme 9 Pro+ 5G (Aurora Green, 256 GB)',
#        'SAMSUNG Galaxy A04s (Black, 64 GB)',
#        'Nokia C01 Plus (Grey, 32 GB)', 'itel MagicX Play',
#        'MOTOROLA g42 (Atlantic Green, 64 GB)',
#        'MarQ by Flipkart M70 Shakti',
#        'REDMI 11 Prime 5G (Meadow Green, 64 GB)',
#        'REDMI 10 Prime 2022 (Astral White, 64 GB)',
#        'itel A27 (Silver Purple, 32 GB)', 'itel A27 (Deep Grey, 32 GB)',
#        'LAVA A1 Super 2021', 'realme C31 (Dark Green, 32 GB)',
#        'REDMI 9 Activ (Carbon Black, 64 GB)',
#        'REDMI 9 Activ (Metallic Purple, 64 GB)', 'LAVA A5',
#        'IQOO Z6 Lite 5G (Without Charger) (Mystic Night, 64 GB)',
#        'Redmi 9A (Midnight Black, 32 GB)', 'Kechaoda K9',
#        'Tecno Spark 8 (Turquoise Cyan, 64 GB)',
#        'OPPO A53 (Mint Cream, 64 GB)',
#        'MOTOROLA g42 (Metallic Rose, 64 GB)',
#        'realme C25_Y (Glacier Blue, 64 GB)',
#        'REDMI Note 11 Pro (Phantom White, 128 GB)', 'KARBONN K9 Yuva',
#        'vivo V23 Pro 5G (Sunshine Gold, 128 GB)',
#        'realme 9 5G SE (Starry Glow, 128 GB)',
#        'REDMI Note 10S (Deep Sea Blue, 128 GB)',
#        'ASUS ROG 5s (Black, 128 GB)',
#        'realme 9 5G SE (Azure Glow, 128 GB)',
#        'SAMSUNG Galaxy S23 5G (Cream, 256 GB)',
#        'REDMI Note 11T 5G (Aquamarine Blue, 128 GB)',
#        'Tecno Pova 3 (Eco Black, 128 GB)',
#        'Tecno Pova 3 (Tech Silver, 64 GB)',
#        'vivo Y75 (Moonlight Shadow, 128 GB)',
#        'realme C21Y (Cross Blue, 32 GB)',
#        'Infinix Smart 6 Plus (Miracle Black, 64 GB)',
#        'REDMI K50i (Quick Silver, 128 GB)',
#        'APPLE iPhone 12 (Green, 64 GB)',
#        'realme GT Master Edition (Luna White, 128 GB)',
#        'MOTOROLA Edge 30 Fusion (Solar Gold, 128 GB)',
#        'realme 9i (Prism Black, 128 GB)',
#        'realme 9i (Prism Black, 64 GB)', 'Nokia 8210 4G DS',
#        'OPPO A17k (Blue, 64 GB)', 'itel Vision3 (Jewel Blue, 32 GB)',
#        'Tecno Pova 3 (Tech Silver, 128 GB)', 'Motorola a50',
#        'realme GT Master Edition (Cosmos Black, 128 GB)', 'Cellecor E3',
#        'itel it2163S', 'GFive U220i',
#        'realme 8s 5G (Universe Blue, 128 GB)',
#        'SAMSUNG GALAXY M13 5G (?Stardust Brown, 128 GB)',
#        'SAMSUNG Galaxy S22 Plus 5G (Green, 128 GB)',
#        'SAMSUNG Galaxy A04 (Green, 128 GB)',
#        'SAMSUNG Galaxy S23 5G (Lavender, 256 GB)',
#        'Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)',
#        'APPLE iPhone 12 (Blue, 64 GB)',
#        'SAMSUNG Galaxy M13 (Aqua Green, 128 GB)', 'Nokia 8210 4G',
#        'KARBONN K9', 'realme Narzo 50A (Oxygen Blue, 64 GB)',
#        'realme GT Master Edition (Cosmos Black, 256 GB)',
#        'APPLE iPhone 14 ((PRODUCT)RED, 256 GB)',
#        'SAMSUNG Galaxy A13 (Blue, 128 GB)',
#        'APPLE iPhone 14 Plus ((PRODUCT)RED, 256 GB)',
#        'Tecno Pop 5 LTE (Ice Blue, 32 GB)',
#        'SAMSUNG Galaxy A52 (Awesome Black, 128 GB)',
#        'realme C25s (Watery Grey, 128 GB)',
#        'MOTOROLA G51 5G (Indigo Blue, 64 GB)',
#        'Infinix Note 11s Free Fire Edition (Mithril Grey, 128 GB)',
#        'POCO M2 Pro (Out of the Blue, 64 GB)',
#        'Infinix Note 11s Free Fire Edition (Haze Green, 128 GB)',
#        'REDMI Note 10S (Cosmic Purple, 128 GB)', 'Nokia 105DS PLUS',
#        'I Kall K37', 'Micromax J2', 'Kechaoda K-9',
#        'realme Narzo 50i (Carbon Black, 64 GB)',
#        'realme Narzo 50i (Carbon Black, 32 GB)',
#        'OPPO F21S PRO (Dawnlight Gold, 128 GB)',
#        'SAMSUNG Galaxy M32 Prime Edition (Light Blue, 64 GB)',
#        'itel A27 (Crystal Blue, 32 GB)',
#        'Tecno Spark 8C (Magnet Black, 64 GB)',
#        'POCO M2 Pro (Two Shades of Black, 128 GB)',
#        'vivo Y15c (Mystic Blue, 32 GB)',
#        'MOTOROLA g31 (Meteorite Grey, 128 GB)',
#        'REDMI 10A (CHARCOAL BLACK, 128 GB)',
#        'Xiaomi 11Lite NE (Vinyl Black, 128 GB)',
#        'realme Narzo 20 (Glory Silver, 64 GB)', 'itel Muzik 110',
#        'APPLE iPhone 14 Plus (Blue, 256 GB)', 'itel Power200',
#        'POCO X3 Pro (Steel Blue, 128 GB)',
#        'realme Narzo 30 Pro 5G (Blade Silver, 128 GB)',
#        'realme 9 5G (Supersonic Black, 64 GB)',
#        'SAMSUNG Galaxy A13 (Peach, 64 GB)',
#        'SAMSUNG Galaxy S23 Ultra 5G (Green, 256 GB)',
#        'Tecno Pop 5 LTE (Deepsea Luster, 32 GB)', 'Nokia 105 SS 2021',
#        'realme Narzo 30 (Racing Silver, 128 GB)',
#        'REDMI K50i (Phantom Blue, 256 GB)',
#        'Infinix Note 11 (Celestial Snow, 128 GB)',
#        'REDMI Note 11 Pro (Star blue, 128 GB)',
#        'SAMSUNG Galaxy A33 (Awesome Peach, 128 GB)', 'Snexian GURU 310',
#        'POCO F3 GT 5G (Predator Black, 128 GB)',
#        'REDMI Note 10 Pro Max (Dark Nebula, 128 GB)',
#        'Mi 11X Pro 5G (Celestial Silver, 128 GB)',
#        'SAMSUNG Galaxy A03 (Blue, 32 GB)',
#        'APPLE iPhone 13 (Midnight, 512 GB)',
#        'OnePlus 10 Pro 5G (Emerald Forest, 256 GB)',
#        'OPPO A74 5G BLACK (Fluid Black, 128 GB)', 'DIZO Star 300',
#        'itel Vision2S (Deep Blue, 32 GB)', 'itel IT2163',
#        'SAMSUNG Galaxy A53 (Awesome Peach, 128 GB)',
#        'POCO M3 (Power Black, 64 GB)', 'itel it5026'], dtype=object)

# %%
mobile_df.shape
# Out:
# (702, 13)
